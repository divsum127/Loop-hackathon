# %%
'''
importing class Nodule(), class CTScan(), helper fuctions and tunable parameters
'''
from config import *
from nodule import Nodule
from nodule import CTScan
from helper_functions import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 '''
#       2 importing class Nodule(), class CTScan(), helper fuctions and tunable parameters
#       3 '''
#       4 from config import *
# ----> 5 from nodule import Nodule
#       6 from nodule import CTScan
#       7 from helper_functions import *
#
# File c:\Users\Shahu Patil\Downloads\Qure_first_2_weeks\nodule.py:3
#       1 from nodule import *
#       2 from config import *
# ----> 3 from helper_functions import *
#       4 import config
#       5 import numpy as np
#
# File c:\Users\Shahu Patil\Downloads\Qure_first_2_weeks\helper_functions.py:7
#       5 import time
#       6 import pandas as pd
# ----> 7 import SimpleITK as sitk
#       8 import ipywidgets as widgets
#       9 from IPython.display import display, clear_output
#
# ModuleNotFoundError: No module named 'SimpleITK'

# %%
'''
generating a synthetic nodule
'''
test_nodule = Nodule()
nodule_mat = test_nodule.nodule_pipeline(nodule_type = "lobulated")

# %%
'''
merging the synthetic nodule with CTScan
'''
test_ct = CTScan()
test_ct.ct_pipeline(nodule= test_nodule, region="right_apical")

# %%
d1 = vars(test_nodule)
d2 = vars(test_ct)
all_keys = sorted(set(d1) | set(d2))
print(f"{'Attribute':<20} | {'Nodule':<15} | {'CTScan':<15}")
print("-" * 55)
for k in all_keys:
    t1 = type(d1[k]).__name__ if k in d1 else "-"
    t2 = type(d2[k]).__name__ if k in d2 else "-"
    print(f"{k:<20} | {t1:<15} | {t2:<15}")
